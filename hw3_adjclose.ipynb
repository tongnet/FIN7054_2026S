# %% [markdown]
# <a href="https://colab.research.google.com/github/tongnet/FIN7054_2026S/blob/main/hw3_adjclose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

data = yf.Ticker("TRV").history(start="2020-01-01", actions=True, auto_adjust=False)

# keep only the raw fields you want
data = data[["Open", "High", "Low", "Close", "Adj Close", "Volume", "Dividends", "Stock Splits"]]

print(data.tail())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-03-17 00:00:00-04:00  308.269989  308.980011  305.929993  306.329987
# 2026-03-18 00:00:00-04:00  305.190002  306.000000  299.029999  299.250000
# 2026-03-19 00:00:00-04:00  299.820007  300.880005  294.630005  296.839996
# 2026-03-20 00:00:00-04:00  296.489990  299.769989  295.029999  296.600006
# 2026-03-23 00:00:00-04:00  300.920013  301.774994  294.500000  295.839996
#
#                             Adj Close   Volume  Dividends  Stock Splits
# Date
# 2026-03-17 00:00:00-04:00  306.329987  1271300        0.0           0.0
# 2026-03-18 00:00:00-04:00  299.250000  1269300        0.0           0.0
# 2026-03-19 00:00:00-04:00  296.839996  1414700        0.0           0.0
# 2026-03-20 00:00:00-04:00  296.600006  4429700        0.0           0.0
# 2026-03-23 00:00:00-04:00  295.839996   839923        0.0           0.0
